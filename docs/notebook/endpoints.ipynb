# %% [markdown]
# # Vitrasa Bus Line Data Extractor
#
# This Python script fetches essential bus line data from the Vitrasa website. It extracts a hidden JSON dataset containing **bus line IDs, names, and colors**, then organizes this information into a Python dictionary for easy access by each **`idBusLine`**.

# %%
import requests
from bs4 import BeautifulSoup
import json
import re

url = "https://www.vitrasa.es/lineas-y-horarios/todas-las-lineas"

# --- Step 1: Fetch the HTML content ---
try:
    response = requests.get(url, timeout=10)
    response.raise_for_status()
    html_content = response.text
except requests.exceptions.RequestException as e:
    print(f"Error fetching HTML: {e}")
    exit()

# --- Step 2: Parse the HTML ---
soup = BeautifulSoup(html_content, 'html.parser')

# --- Step 3: Find the script tag containing 'jsonLineas' and extract the JSON string ---
json_data_string = None
script_tags = soup.find_all('script')

for script in script_tags:
    if script.string and 'const jsonLineas =' in script.string:
        match = re.search(r'const jsonLineas = (\[.*?\]);', script.string, re.DOTALL)
        if match:
            json_data_string = match.group(1)
            break

# --- Step 4: Convert the extracted string to a Python object ---
if json_data_string:
    try:
        lineas_data = json.loads(json_data_string)
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON from script content: {e}")
else:
    print("Could not find the 'jsonLineas' data in any script tag.")
    exit()

# --- Step 5: Format the data into a Python dictionary using 'idBusLine' as key ---
bus_lines_dict = {}
if lineas_data:
    for line in lineas_data:
        if "idBusLine" in line:
            bus_lines_dict[line["idBusLine"]] = line
            del bus_lines_dict[line["idBusLine"]]["idBusLine"] 
    print(json.dumps(bus_lines_dict, indent=4, ensure_ascii=False))
else:
    print("No bus line data available to format into a dictionary.")
    exit()
# Out:
# {
#     "1": {
#         "idBusSAE": "C1",
#         "descBusLine": "CIRCULAR CENTRO",
#         "color": "#ED4713"
#     },
#     "3001": {
#         "idBusSAE": "C3d",
#         "descBusLine": "BOUZAS/COIA – ENCARNACIÓN (P.E.FADRIQUE)",
#         "color": "#FFCC00"
#     },
#     "3002": {
#         "idBusSAE": "C3i",
#         "descBusLine": "BOUZAS/COIA – ENCARNACIÓN (PZA. ESPAÑA)",
#         "color": "#FFCC00"
#     },
#     "4001": {
#         "idBusSAE": "4A",
#         "descBusLine": "ARAGÓN - COIA",
#         "color": "#009900"
#     },
#     "4003": {
#         "idBusSAE": "4C",
#         "descBusLine": "G. ESPINO - COIA",
#         "color": "#009900"
#     },
#     "5001": {
#         "idBusSAE": "5A",
#         "descBusLine": "NAVIA-TRV. DE VIGO ",
#         "color": "#00B0F0"
#     },
#     "5004": {
#         "idBusSAE": "5B",
#         "descBusLine": "NAVIA-S. BADÍA ",
#         "color": "#00B0F0"
#     },
#     "6": {
#         "idBusSAE": "6",
#         "descBusLine": "HOSP. ALVARO CUNQUEIRO - BEADE – PZA. ESPAÑA",
#         "color": "#CC3399"
#     },
#     "7": {
#         "idBusSAE": "7",
#         "descBusLine": "PZA. ESPAÑA – GARRIDA / ZAMÁNS / SOBREIRA",
#         "color": "#96DC99"
#     },
#     "9002": {
#         "idBusSAE": "9B",
#         "descBusLine": "RECONQUISTA - RABADEIRA",
#         "color": "#F4CA8C"
#     },
#     "10": {
#         "idBusSAE": "10",
#         "descBusLine": "TEIS – CANIDO – SAIÁNS",
#         "color": "#993300"
#     },
#     "11": {
#         "idBusSAE": "11",
#         "descBusLine": "SAN MIGUEL - CABRAL",
#         "color": "#E20026"
#     },
#     "1201": {
#         "idBusSAE": "12A",
#         "descBusLine": "SAIÁNS – MUÍÑOS – HOSP. MEIXOEIRO",
#         "color": "#6A96BE"
#     },
#     "1202": {
#         "idBusSAE": "12B",
#         "descBusLine": "HOSP. ALVARO CUNQUEIRO – HOSP. MEIXOEIRO",
#         "color": "#6A96BE"
#     },
#     "13": {
#         "idBusSAE": "13",
#         "descBusLine": "TEIXUGUEIRAS – HOSP. MEIXOEIRO",
#         "color": "#00B0F0"
#     },
#     "14": {
#         "idBusSAE": "14",
#         "descBusLine": "CHANS – GRAN VÍA",
#         "color": "#818E7E"
#     },
#     "1501": {
#         "idBusSAE": "15A",
#         "descBusLine": "CABRAL - SAMIL",
#         "color": "#D8A8CE"
#     },
#     "1506": {
#         "idBusSAE": "15B",
#         "descBusLine": "XESTOSO - SAMIL / NAVIA",
#         "color": "#D8A8CE"
#     },
#     "1507": {
#         "idBusSAE": "15C",
#         "descBusLine": "UNIVERSIDADE – SAMIL / NAVIA",
#         "color": "#D8A8A8"
#     },
#     "16": {
#         "idBusSAE": "16",
#         "descBusLine": "COIA – ESTACIÓN FF.CC. (GUIXAR)",
#         "color": "#818E7E"
#     },
#     "17": {
#         "idBusSAE": "17",
#         "descBusLine": "MATAMÁ (BALSA) – A GUÍA / RÍOS",
#         "color": "#D6F51F"
#     },
#     "18": {
#         "idBusSAE": "18A",
#         "descBusLine": "\tAREAL/COLÓN - SÁRDOMA/POULEIRA",
#         "color": "#D450A8"
#     },
#     "1801": {
#         "idBusSAE": "18B",
#         "descBusLine": "URZAIZ / P.ESPAÑA - POULEIRA",
#         "color": "#000000"
#     },
#     "1802": {
#         "idBusSAE": "18H",
#         "descBusLine": "URZAIZ / P. ESPAÑA - H. ALV. CUNQUEIRO",
#         "color": "#000000"
#     },
#     "23": {
#         "idBusSAE": "23",
#         "descBusLine": "M. ECHEGARAY – G. ESPINO",
#         "color": "#0046D2"
#     },
#     "24": {
#         "idBusSAE": "24",
#         "descBusLine": "POULO – ESTACIÓN FF.CC. (GUIXAR)",
#         "color": "#BFBFBF"
#     },
#     "25": {
#         "idBusSAE": "25",
#         "descBusLine": "PZA. ESPAÑA – SABAXÁNS / CAEIRO",
#         "color": "#AC6404"
#     },
#     "27": {
#         "idBusSAE": "27",
#         "descBusLine": "BEADE (C. CULTURAL) – RABADEIRA",
#         "color": "#704A2A"
#     },
#     "28": {
#         "idBusSAE": "28",
#         "descBusLine": "VIGOZOO - SAN PAIO - BOUZAS",
#         "color": "#B0BDFE"
#     },
#     "29": {
#         "idBusSAE": "29",
#         "descBusLine": "FRAGOSELO / S. ANDRÉS – PZA. ESPAÑA",
#         "color": "#F8B85A"
#     },
#     "31": {
#         "idBusSAE": "31",
#         "descBusLine": "SAN LORENZO – HOSP. MEIXOEIRO",
#         "color": "#FFFF00"
#     },
#     "8": {
#         "idBusSAE": "A",
#         "descBusLine": "ARENAL – PORTO / UNIVERSIDAD",
#         "color": "#77298F"
#     },
#     "104": {
#         "idBusSAE": "H",
#         "descBusLine": "NAVIA - BOUZAS - HOSPITAL ALVARO CUNQUEIRO",
#         "color": "#0060A8"
#     },
#     "101": {
#         "idBusSAE": "H1",
#         "descBusLine": "POLICARPO SANZ – HOSPITAL ÁLVARO CUNQUEIRO",
#         "color": "#0060A8"
#     },
#     "102": {
#         "idBusSAE": "H2",
#         "descBusLine": "GREGORIO ESPINO – HOSPITAL ÁLVARO CUNQU",
#         "color": "#0060A8"
#     },
#     "105": {
#         "idBusSAE": "H3",
#         "descBusLine": "GARCÍA BARBÓN – HOSPITAL ÁLVARO CUNQUEIRO",
#         "color": "#0060A8"
#     },
#     "751": {
#         "idBusSAE": "LZD",
#         "descBusLine": "STELLANTIS",
#         "color": "#3D4EA7"
#     },
#     "30": {
#         "idBusSAE": "N1 ",
#         "descBusLine": "SAMIL  – BUENOS AIRES",
#         "color": "#BFBFBF"
#     },
#     "3305": {
#         "idBusSAE": "N4",
#         "descBusLine": "NAVIA - G. ESPINO",
#         "color": ""
#     },
#     "301": {
#         "idBusSAE": "PSA1",
#         "descBusLine": "STELLANTIS",
#         "color": "#009900"
#     },
#     "4004": {
#         "idBusSAE": "PSA4",
#         "descBusLine": "STELLANTIS",
#         "color": "#009900"
#     },
#     "304": {
#         "idBusSAE": "PTL",
#         "descBusLine": "PARQUE TECNOLÓGICO",
#         "color": "#96DC99"
#     },
#     "500": {
#         "idBusSAE": "TURISTICO",
#         "descBusLine": "TURISTICO",
#         "color": ""
#     },
#     "201": {
#         "idBusSAE": "U1 ",
#         "descBusLine": "LANZADERA PZA. AMÉRICA – UNIVERSIDAD",
#         "color": "#AC6404"
#     },
#     "202": {
#         "idBusSAE": "U2 ",
#         "descBusLine": "LANZADERA PZA. DE ESPAÑA – UNIVERSIDAD",
#         "color": "#AC6404"
#     }
# }

# %% [markdown]
# # Vitrasa Bus Line Data Request & Filtering
# This Python script sends a *POST request* to the Vitrasa website to retrieve bus line data. It processes the received JSON and then *pretty-prints* the cleaned information. The script also includes robust error handling for network or JSON parsing issues.

# %% [markdown]
# ## Data Request
# This part of the script constructs and sends a *POST request* to the Vitrasa web service, including specific parameters and a `idBusLine`. It then verifies the success of the HTTP request.

# %%
import requests

base_url = "https://www.vitrasa.es/lineas-y-horarios/todas-las-lineas"

params = {
    "p_p_id": "mx_com_ado_all_lines_web_AllLinesPortlet_INSTANCE_zDp1QpJtQsKA",
    "p_p_lifecycle": "2",
    "p_p_state": "normal",
    "p_p_mode": "view",
    "p_p_cacheability": "cacheLevelPage"
}

data = {"idBusLine": "104"}

response = requests.post(base_url, params=params, data=data)
response.raise_for_status()

# %% [markdown]
# ## JSON Processing & Filtering
# This section defines a helper function to *recursively remove `geometry` fields* for cleaner output. It then parses the server's response into JSON, applies this filtering, and *pretty-prints the resulting, human-readable data*. Robust error handling is included for invalid JSON responses.

# %%
import json

def remove_geometry_field(obj):
    """
    Recursively removes all keys named 'geometry' from dictionaries within
    a JSON-like Python object (dict or list).
    Returns a new object with 'geometry' fields removed.
    """
    if isinstance(obj, dict):
        new_dict = {}
        for key, value in obj.items():
            if key == "geometry":
                continue
            new_dict[key] = remove_geometry_field(value)
        return new_dict
    elif isinstance(obj, list):
        return [remove_geometry_field(elem) for elem in obj]
    else:
        return obj

try:
    raw_json_content = response.json()
    filtered_json_content = remove_geometry_field(raw_json_content)
    print(json.dumps(filtered_json_content, indent=4, ensure_ascii=False))
except json.JSONDecodeError:
    print("The server did not return valid JSON.")
# Out:
# {
#     "idBusLine": "C3i",
#     "idBusSAE": "C3i",
#     "descBusLine": "BOUZAS/COIA – ENCARNACIÓN (PZA. ESPAÑA)",
#     "color": "#FFCC00",
#     "geographic_data_structure": {
#         "initial_map_coordinates": [
#             "-7.855431773723",
#             "42.328299075595"
#         ]
#     },
#     "scale": "13",
#     "distance": "10",
#     "outTrip": {
#         "type": "FeatureCollection",
#         "features": [
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "3002"
#                 },
#                 "style": {
#                     "fill": "#da291d",
#                     "strokeWidth": "3",
#                     "fillOpacity": "0.3"
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "14299",
#                     "node": "14299",
#                     "idBusSAE": "14299",
#                     "desBusStop": "Avda. de Samil (frente Verbum)",
#                     "busLineCrossing": [
#                         "30|N1 ",
#                         "1501|15A"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "1920",
#                     "node": "1920",
#                     "idBusSAE": "1920",
#                     "desBusStop": "Avda. de Europa, 101",
#                     "busLineCrossing": [
#                         "30|N1 ",
#                         "1501|15A",
#                         "3001|C3d",
#                         "4003|4C"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "1900",
#                     "node": "1900",
#                     "idBusSAE": "1900",
#                     "desBusStop": "Avda. de Europa (cruce Rúa do Bravo)",
#                     "busLineCrossing": [
#                         "30|N1 ",
#                         "1501|15A",
#                         "3001|C3d",
#                         "4003|4C"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "1890",
#                     "node": "1890",
#                     "idBusSAE": "1890",
#                     "desBusStop": "Avda. de Europa, 23",
#                     "busLineCrossing": [
#                         "30|N1 ",
#                         "1201|12A",
#                         "1501|15A",
#                         "3001|C3d",
#                         "4003|4C"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "1880",
#                     "node": "1880",
#                     "idBusSAE": "1880",
#                     "desBusStop": "Avda. de Europa (cruce Rúa das Teixugueiras)",
#                     "busLineCrossing": [
#                         "30|N1 ",
#                         "1201|12A",
#                         "1501|15A",
#                         "3001|C3d",
#                         "4003|4C"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "14123",
#                     "node": "14123",
#                     "idBusSAE": "14123",
#                     "desBusStop": "Rúa do Porriño, 9",
#                     "busLineCrossing": [
#                         "11|11",
#                         "1501|15A",
#                         "1506|15B",
#                         "3001|C3d",
#                         "4001|4A",
#                         "4003|4C",
#                         "5004|5B"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "6650",
#                     "node": "6650",
#                     "idBusSAE": "6650",
#                     "desBusStop": "Rúa do Porriño (Instituto)",
#                     "busLineCrossing": [
#                         "1506|15B",
#                         "3001|C3d",
#                         "5004|5B"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "1320",
#                     "node": "1320",
#                     "idBusSAE": "1320",
#                     "desBusStop": "Avda. de Castelao, 87",
#                     "busLineCrossing": [
#                         "10|10",
#                         "30|N1 ",
#                         "1201|12A"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "1310",
#                     "node": "1310",
#                     "idBusSAE": "1310",
#                     "desBusStop": "Avda. de Castelao, 73",
#                     "busLineCrossing": [
#                         "10|10",
#                         "11|11",
#                         "30|N1 ",
#                         "1201|12A",
#                         "1501|15A",
#                         "4001|4A",
#                         "4003|4C"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "20075",
#                     "node": "20075",
#                     "idBusSAE": "20075",
#                     "desBusStop": "Avda. de Castelao, 65",
#                     "busLineCrossing": [
#                         "10|10",
#                         "11|11",
#                         "30|N1 ",
#                         "1201|12A",
#                         "1501|15A",
#                         "4001|4A",
#                         "4003|4C"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "1280",
#                     "node": "1280",
#                     "idBusSAE": "1280",
#                     "desBusStop": "Avda. de Castelao, 41",
#                     "busLineCrossing": [
#                         "10|10",
#                         "11|11",
#                         "30|N1 ",
#                         "1201|12A",
#                         "1501|15A",
#                         "4001|4A",
#                         "4003|4C"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "20076",
#                     "node": "20076",
#                     "idBusSAE": "20076",
#                     "desBusStop": "Avda. de Castelao, 25",
#                     "busLineCrossing": [
#                         "10|10",
#                         "11|11",
#                         "30|N1 ",
#                         "1201|12A",
#                         "1501|15A",
#                         "4001|4A",
#                         "4003|4C"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "1260",
#                     "node": "1260",
#                     "idBusSAE": "1260",
#                     "desBusStop": "Avda. de Castelao, 21",
#                     "busLineCrossing": [
#                         "10|10",
#                         "11|11",
#                         "30|N1 ",
#                         "1201|12A",
#                         "1501|15A",
#                         "4001|4A",
#                         "4003|4C",
#                         "5004|5B"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "14901",
#                     "node": "14901",
#                     "idBusSAE": "14901",
#                     "desBusStop": "Avda. de Castelao, 1",
#                     "busLineCrossing": [
#                         "10|10",
#                         "11|11",
#                         "1501|15A"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "14206",
#                     "node": "14206",
#                     "idBusSAE": "14206",
#                     "desBusStop": "Avda. da Gran Vía (Instituto)",
#                     "busLineCrossing": [
#                         "7|7",
#                         "11|11",
#                         "13|13",
#                         "16|16",
#                         "23|23",
#                         "29|29",
#                         "102|H2",
#                         "1501|15A"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "5650",
#                     "node": "5650",
#                     "idBusSAE": "5650",
#                     "desBusStop": "Avda. da Gran Vía, 185",
#                     "busLineCrossing": [
#                         "7|7",
#                         "11|11",
#                         "13|13",
#                         "16|16",
#                         "23|23",
#                         "29|29",
#                         "102|H2",
#                         "1501|15A"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "5630",
#                     "node": "5630",
#                     "idBusSAE": "5630",
#                     "desBusStop": "Avda. da Gran Vía, 147",
#                     "busLineCrossing": [
#                         "7|7",
#                         "11|11",
#                         "13|13",
#                         "16|16",
#                         "23|23",
#                         "29|29",
#                         "102|H2",
#                         "201|U1 ",
#                         "202|U2 ",
#                         "1501|15A"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "5600",
#                     "node": "5600",
#                     "idBusSAE": "5600",
#                     "desBusStop": "Avda. da Gran Vía, 107",
#                     "busLineCrossing": [
#                         "7|7",
#                         "11|11",
#                         "13|13",
#                         "16|16",
#                         "23|23",
#                         "29|29",
#                         "102|H2",
#                         "1501|15A"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "5690",
#                     "node": "5690",
#                     "idBusSAE": "5690",
#                     "desBusStop": "Avda. da Gran Vía, 85",
#                     "busLineCrossing": [
#                         "7|7",
#                         "11|11",
#                         "13|13",
#                         "16|16",
#                         "23|23",
#                         "29|29",
#                         "102|H2",
#                         "1501|15A"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "6550",
#                     "node": "6550",
#                     "idBusSAE": "6550",
#                     "desBusStop": "Rúa de Pizarro, 10",
#                     "busLineCrossing": [
#                         "6|6",
#                         "11|11",
#                         "23|23",
#                         "25|25",
#                         "28|28",
#                         "29|29",
#                         "1501|15A"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "20177",
#                     "node": "20177",
#                     "idBusSAE": "20177",
#                     "desBusStop": "Rúa de Pizarro, 16",
#                     "busLineCrossing": [
#                         "6|6",
#                         "11|11",
#                         "23|23",
#                         "25|25",
#                         "28|28",
#                         "1501|15A"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "6560",
#                     "node": "6560",
#                     "idBusSAE": "6560",
#                     "desBusStop": "Rúa de Pizarro, 34",
#                     "busLineCrossing": [
#                         "6|6",
#                         "11|11",
#                         "23|23",
#                         "25|25",
#                         "27|27",
#                         "28|28",
#                         "1501|15A"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "8610",
#                     "node": "8610",
#                     "idBusSAE": "8610",
#                     "desBusStop": "Rúa da Travesía de Vigo, 8",
#                     "busLineCrossing": [
#                         "6|6",
#                         "8|A",
#                         "11|11",
#                         "23|23",
#                         "24|24",
#                         "25|25",
#                         "27|27",
#                         "28|28",
#                         "30|N1 ",
#                         "1501|15A",
#                         "1506|15B",
#                         "1507|15C",
#                         "4001|4A",
#                         "4003|4C",
#                         "5001|5A",
#                         "9002|9B"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "8580",
#                     "node": "8580",
#                     "idBusSAE": "8580",
#                     "desBusStop": "Rúa da Travesía de Vigo, 32",
#                     "busLineCrossing": [
#                         "30|N1 ",
#                         "31|31",
#                         "5001|5A"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "8620",
#                     "node": "8620",
#                     "idBusSAE": "8620",
#                     "desBusStop": "Rúa da Travesía de Vigo, 82",
#                     "busLineCrossing": [
#                         "30|N1 ",
#                         "5001|5A"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "8510",
#                     "node": "8510",
#                     "idBusSAE": "8510",
#                     "desBusStop": "Rúa da Travesía de Vigo, 124",
#                     "busLineCrossing": [
#                         "30|N1 ",
#                         "5001|5A"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "8530",
#                     "node": "8530",
#                     "idBusSAE": "8530",
#                     "desBusStop": "Rúa da Travesía de Vigo, 158",
#                     "busLineCrossing": [
#                         "30|N1 ",
#                         "5001|5A"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "14126",
#                     "node": "14126",
#                     "idBusSAE": "14126",
#                     "desBusStop": "Rúa da Travesía de Vigo, 194",
#                     "busLineCrossing": [
#                         "30|N1 ",
#                         "5001|5A"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "8490",
#                     "node": "8490",
#                     "idBusSAE": "8490",
#                     "desBusStop": "Rúa da Travesía de Vigo, 202",
#                     "busLineCrossing": [
#                         "30|N1 ",
#                         "105|H3",
#                         "5001|5A"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "8550",
#                     "node": "8550",
#                     "idBusSAE": "8550",
#                     "desBusStop": "Rúa da Travesía de Vigo, 220",
#                     "busLineCrossing": [
#                         "30|N1 ",
#                         "105|H3",
#                         "5001|5A",
#                         "5004|5B"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "230",
#                     "node": "230",
#                     "idBusSAE": "230",
#                     "desBusStop": "Rúa de Ángel de Lema, 14",
#                     "busLineCrossing": [
#                         "10|10"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "20053",
#                     "node": "20053",
#                     "idBusSAE": "20053",
#                     "desBusStop": "Rúa de Ángel de Lema (cruce Paraixal)",
#                     "busLineCrossing": [
#                         "10|10"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "190",
#                     "node": "190",
#                     "idBusSAE": "190",
#                     "desBusStop": "Rúa de Ángel de Lema, 58",
#                     "busLineCrossing": [
#                         "10|10"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "200",
#                     "node": "200",
#                     "idBusSAE": "200",
#                     "desBusStop": "Rúa de Ángel de Lema, 100",
#                     "busLineCrossing": [
#                         "10|10"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "210",
#                     "node": "210",
#                     "idBusSAE": "210",
#                     "desBusStop": "Rúa de Ángel de Lema, 140",
#                     "busLineCrossing": [
#                         "10|10"
#                     ]
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "2070",
#                     "node": "2070",
#                     "idBusSAE": "2070",
#                     "desBusStop": "Avda. de Redondela, 109",
#                     "busLineCrossing": []
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "2100",
#                     "node": "2100",
#                     "idBusSAE": "2100",
#                     "desBusStop": "Avda. de Redondela, 47",
#                     "busLineCrossing": []
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "2080",
#                     "node": "2080",
#                     "idBusSAE": "2080",
#                     "desBusStop": "Avda. de Redondela, 19",
#                     "busLineCrossing": []
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "5030",
#                     "node": "5030",
#                     "idBusSAE": "5030",
#                     "desBusStop": "Avda. de Redondela (fronte 28)",
#                     "busLineCrossing": []
#                 }
#             },
#             {
#                 "type": "Feature",
#                 "properties": {
#                     "idBusLine": "C3i",
#                     "color": "#FFCC00",
#                     "idBusStop": "1710",
#                     "node": "1710",
#                     "idBusSAE": "1710",
#                     "desBusStop": "Avda. de Vigo, 6",
#                     "busLineCrossing": []
#                 }
#             }
#         ]
#     },
#     "backTrip": {
#         "type": "",
#         "features": []
#     }
# }

# %% [markdown]
# # Vitrasa Bus Stop ETA Retrieval & Processing
# This Python script efficiently retrieves estimated arrival times (ETAs) for a specified Vitrasa bus stop by sending a *POST request* to the API. It then expertly *processes the unique nested JSON response*, extracting the core data and presenting it in a clean, readable format, with built-in error handling for seamless operation.

# %% [markdown]
# ## Requesting Live Stop Data
# This section of the script *sends a POST request* to the Vitrasa API. It targets a specific bus stop to retrieve its estimated times of arrival (ETAs). The request includes various Liferay portlet parameters and a command to `getETAS`, ensuring the correct data is requested.

# %%
import requests

base_url = "https://www.vitrasa.es/detalleparada"

params = {
    "p_p_id": "com_ado_portlet_parada_AdoParadaPortlet_INSTANCE_e3K3ns9GxruP",
    "p_p_lifecycle": "2",
    "p_p_state": "normal",
    "p_p_mode": "view",
    "p_p_cacheability": "cacheLevelPage",
    "_com_ado_portlet_parada_AdoParadaPortlet_INSTANCE_e3K3ns9GxruP_cmd": "getETAS"
}

data = {"_com_ado_portlet_parada_AdoParadaPortlet_INSTANCE_e3K3ns9GxruP_busStopID": "14901"}

response = requests.post(base_url, params=params, data=data)
response.raise_for_status()

# %% [markdown]
# ## Processing Nested JSON Response
# This part handles the *parsing and cleaning of the received JSON data*. It defines a function specifically designed to correctly interpret the API's unusual response format, where the main data is a JSON string nested within another the field `jsontraffics2`. The parsed, readable data is then *pretty-printed* to the console, with robust error handling for any JSON decoding issues.

# %%
import json

def parse_nested_vitrasa_json(json_response: dict) -> list | None:
    """
    Parses a JSON response from Vitrasa that contains a nested JSON string
    under the 'jsontraffics2' key.
    """
    json_string_data = json_response.get("jsontraffics2")

    if json_string_data:
        try:
            normal_dict_list = json.loads(json_string_data)
            return normal_dict_list
        except json.JSONDecodeError as e:
            print(f"Error decoding the nested JSON string from 'jsontraffics2': {e}")
            return None
    else:
        print("'jsontraffics2' key not found in the provided JSON response.")
        return None

try:
    raw_json_content = response.json()
    filtered_json_content = parse_nested_vitrasa_json(raw_json_content)
    print(json.dumps(filtered_json_content, indent=4, ensure_ascii=False))
except json.JSONDecodeError:
    print("The server did not return valid JSON.")
# Out:
# [
#     {
#         "idBusLine": "3002",
#         "idBusSAE": "C3i",
#         "desBusLine": "BOUZAS/COIA – ENCARNACIÓN (PZA. ESPAÑA)",
#         "desLocalCompany": "VITRASA",
#         "desDepartureBusStop": "Rúa do Porriño, 9",
#         "desArrivalBusStop": "Avda. de Vigo, 6",
#         "arrivalTime": "",
#         "minutesArrive": 1
#     },
#     {
#         "idBusLine": "1501",
#         "idBusSAE": "15A",
#         "desBusLine": "CABRAL - SAMIL",
#         "desLocalCompany": "VITRASA",
#         "desDepartureBusStop": "Avda. de Samil (frente Verbum)",
#         "desArrivalBusStop": "Avda. da Ponte, 31",
#         "arrivalTime": "",
#         "minutesArrive": 4
#     },
#     {
#         "idBusLine": "3002",
#         "idBusSAE": "C3i",
#         "desBusLine": "BOUZAS/COIA – ENCARNACIÓN (PZA. ESPAÑA)",
#         "desLocalCompany": "VITRASA",
#         "desDepartureBusStop": "Rúa do Porriño, 9",
#         "desArrivalBusStop": "Avda. de Vigo, 6",
#         "arrivalTime": "",
#         "minutesArrive": 17
#     },
#     {
#         "idBusLine": "10",
#         "idBusSAE": "10",
#         "desBusLine": "TEIS – CANIDO – SAIÁNS",
#         "desLocalCompany": "VITRASA",
#         "desDepartureBusStop": "Baixada á Praia, 4",
#         "desArrivalBusStop": "Camiño Padín (Rotonda Autoestrada)",
#         "arrivalTime": "",
#         "minutesArrive": 31
#     },
#     {
#         "idBusLine": "1501",
#         "idBusSAE": "15A",
#         "desBusLine": "CABRAL - SAMIL",
#         "desLocalCompany": "VITRASA",
#         "desDepartureBusStop": "Avda. de Samil (frente Verbum)",
#         "desArrivalBusStop": "Avda. da Ponte, 31",
#         "arrivalTime": "",
#         "minutesArrive": 36
#     },
#     {
#         "idBusLine": "3002",
#         "idBusSAE": "C3i",
#         "desBusLine": "BOUZAS/COIA – ENCARNACIÓN (PZA. ESPAÑA)",
#         "desLocalCompany": "VITRASA",
#         "desDepartureBusStop": "Rúa do Porriño, 9",
#         "desArrivalBusStop": "Avda. de Vigo, 6",
#         "arrivalTime": "",
#         "minutesArrive": 54
#     },
#     {
#         "idBusLine": "3002",
#         "idBusSAE": "C3i",
#         "desBusLine": "BOUZAS/COIA – ENCARNACIÓN (PZA. ESPAÑA)",
#         "desLocalCompany": "VITRASA",
#         "desDepartureBusStop": "Rúa do Porriño, 9",
#         "desArrivalBusStop": "Avda. de Vigo, 6",
#         "arrivalTime": "",
#         "minutesArrive": 70
#     },
#     {
#         "idBusLine": "10",
#         "idBusSAE": "10",
#         "desBusLine": "TEIS – CANIDO – SAIÁNS",
#         "desLocalCompany": "VITRASA",
#         "desDepartureBusStop": "Baixada á Praia, 4",
#         "desArrivalBusStop": "Camiño Padín (Rotonda Autoestrada)",
#         "arrivalTime": "",
#         "minutesArrive": 91
#     },
#     {
#         "idBusLine": "10",
#         "idBusSAE": "10",
#         "desBusLine": "TEIS – CANIDO – SAIÁNS",
#         "desLocalCompany": "VITRASA",
#         "desDepartureBusStop": "Baixada á Praia, 4",
#         "desArrivalBusStop": "Camiño Padín (Rotonda Autoestrada)",
#         "arrivalTime": "",
#         "minutesArrive": 150
#     }
# ]
